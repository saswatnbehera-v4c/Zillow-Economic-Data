# %%
# %run ../config/project_config

# %%
county_path = f'/Volumes/{CATALOG_NAME}/{SCHEMA_BRONZE}/files/County_time_series_chunk_1.csv'
dict_path = f'/Volumes/{CATALOG_NAME}/{SCHEMA_BRONZE}/files/DataDictionary.csv'

# %%
df_county_time_series = spark.read.csv(county_path, header = True)
df_data_dictionary = spark.read.csv(dict_path, header = True)

# %%
display(df_county_time_series)

# %%
display(df_county_time_series.columns)

# %%
display(df_county_time_series.describe())
