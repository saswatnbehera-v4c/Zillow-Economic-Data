# %%
# %run ./src/utils

# %%
# %run ./config/project_config

# %%
file_name = dbutils.widgets.text('file_name','')
partition_percentage = dbutils.widgets.text('partition_percentage','')
output_dir = dbutils.widgets.text('output_dir', '')
has_header = dbutils.widgets.text('has_header', '')
delimiter = dbutils.widgets.text('delimiter', '')

# %%
file_name = dbutils.widgets.get('file_name')
partition_percentage = dbutils.widgets.get('partition_percentage')
output_dir = dbutils.widgets.get('output_dir')
has_header = dbutils.widgets.get('has_header')
delimiter = dbutils.widgets.get('delimiter')

# %%
csv_file_path = f'/Volumes/{CATALOG_NAME}/{SCHEMA_BRONZE}/files/{file_name}.csv'
output_dir_path = f'/Volumes/{CATALOG_NAME}/{SCHEMA_BRONZE}/files/{output_dir}/'
partition_percentage = ast.literal_eval(partition_percentage)
csv_json_file_path = f'/Volumes/{CATALOG_NAME}/{SCHEMA_BRONZE}/files/{file_name}_chunk_3.csv'
json_file_path = f'/Volumes/{CATALOG_NAME}/{SCHEMA_BRONZE}/files/{file_name}_chunk_3.json'
csv_xml_file_path = f'/Volumes/{CATALOG_NAME}/{SCHEMA_BRONZE}/files/{file_name}_chunk_4.csv'
xml_file_path = f'/Volumes/{CATALOG_NAME}/{SCHEMA_BRONZE}/files/{file_name}_chunk_4.xml'

# %%
print(csv_file_path)

# %%
split_csv(csv_file_path,partition_percentage)

# %%
csv_to_json(csv_json_file_path,json_file_path)

# %%
csv_to_xml(csv_xml_file_path,xml_file_path)
