# %%
# %run ../../config/project_config

# %%
from pyspark.sql import functions as F
from pyspark.sql.functions import col

# %%
df = spark.table(f"{CATALOG_NAME}.{SCHEMA_SILVER}.county_crosswalk_metrics")

# %%
excluded_cols = ["load_dt", "source_file", "_rescued_data"]

# %%
display(df.dtypes)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_1</th><th>_2</th></tr></thead><tbody><tr><td>date</td><td>string</td></tr><tr><td>region_name</td><td>string</td></tr><tr><td>days_on_zillow_all_homes</td><td>string</td></tr><tr><td>inventory_seasonally_adjusted_all_homes</td><td>string</td></tr><tr><td>inventory_raw_all_homes</td><td>string</td></tr><tr><td>median_listing_price_per_sqft_1_bedroom</td><td>string</td></tr><tr><td>median_listing_price_per_sqft_2_bedroom</td><td>string</td></tr><tr><td>median_listing_price_per_sqft_3_bedroom</td><td>string</td></tr><tr><td>median_listing_price_per_sqft_4_bedroom</td><td>string</td></tr><tr><td>median_listing_price_per_sqft_5_bedroom_or_more</td><td>string</td></tr><tr><td>median_listing_price_per_sqft_all_homes</td><td>string</td></tr><tr><td>median_listing_price_per_sqft_condo_coop</td><td>string</td></tr><tr><td>median_listing_price_per_sqft_duplex_triplex</td><td>string</td></tr><tr><td>median_listing_price_per_sqft_single_family_residence</td><td>string</td></tr><tr><td>median_listing_price_1_bedroom</td><td>string</td></tr><tr><td>median_listing_price_2_bedroom</td><td>string</td></tr><tr><td>median_listing_price_3_bedroom</td><td>string</td></tr><tr><td>median_listing_price_4_bedroom</td><td>string</td></tr><tr><td>median_listing_price_5_bedroom_or_more</td><td>string</td></tr><tr><td>median_listing_price_all_homes</td><td>string</td></tr><tr><td>median_listing_price_condo_coop</td><td>string</td></tr><tr><td>median_listing_price_duplex_triplex</td><td>string</td></tr><tr><td>median_listing_price_single_family_residence</td><td>string</td></tr><tr><td>median_pct_of_price_reduction_all_homes</td><td>string</td></tr><tr><td>median_pct_of_price_reduction_condo_coop</td><td>string</td></tr><tr><td>median_pct_of_price_reduction_single_family_residence</td><td>string</td></tr><tr><td>median_price_cut_dollar_all_homes</td><td>string</td></tr><tr><td>median_price_cut_dollar_condo_coop</td><td>string</td></tr><tr><td>median_price_cut_dollar_single_family_residence</td><td>string</td></tr><tr><td>median_rental_price_per_sqft_1_bedroom</td><td>string</td></tr><tr><td>median_rental_price_per_sqft_2_bedroom</td><td>string</td></tr><tr><td>median_rental_price_per_sqft_3_bedroom</td><td>string</td></tr><tr><td>median_rental_price_per_sqft_4_bedroom</td><td>string</td></tr><tr><td>median_rental_price_per_sqft_5_bedroom_or_more</td><td>string</td></tr><tr><td>median_rental_price_per_sqft_all_homes</td><td>string</td></tr><tr><td>median_rental_price_per_sqft_condo_coop</td><td>string</td></tr><tr><td>median_rental_price_per_sqft_duplex_triplex</td><td>string</td></tr><tr><td>median_rental_price_per_sqft_multi_family_residence5_plus_units</td><td>string</td></tr><tr><td>median_rental_price_per_sqft_single_family_residence</td><td>string</td></tr><tr><td>median_rental_price_per_sqft_studio</td><td>string</td></tr><tr><td>median_rental_price_1_bedroom</td><td>string</td></tr><tr><td>median_rental_price_2_bedroom</td><td>string</td></tr><tr><td>median_rental_price_3_bedroom</td><td>string</td></tr><tr><td>median_rental_price_4_bedroom</td><td>string</td></tr><tr><td>median_rental_price_5_bedroom_or_more</td><td>string</td></tr><tr><td>median_rental_price_all_homes</td><td>string</td></tr><tr><td>median_rental_price_condo_coop</td><td>string</td></tr><tr><td>median_rental_price_duplex_triplex</td><td>string</td></tr><tr><td>median_rental_price_multi_family_residence5_plus_units</td><td>string</td></tr><tr><td>median_rental_price_single_family_residence</td><td>string</td></tr><tr><td>median_rental_price_studio</td><td>string</td></tr><tr><td>zhviper_sqft_all_homes</td><td>string</td></tr><tr><td>pct_of_homes_decreasing_in_values_all_homes</td><td>string</td></tr><tr><td>pct_of_homes_increasing_in_values_all_homes</td><td>string</td></tr><tr><td>pct_of_homes_selling_for_gain_all_homes</td><td>string</td></tr><tr><td>pct_of_homes ...

# %%
date_col = "date"
# All columns starting with 'median', 'zhvi', 'zri', 'sale', 'pct', or 'zhvi'
metric_cols = [c for c in df.columns if any(prefix in c for prefix in 
               ['median', 'zhvi', 'zri', 'sale', 'pct', 'price_to_rent', 'inventory'])]

# %%
df_standardized = df.withColumn(date_col, F.to_date(F.col(date_col))) # Date Standardization

for col_name in metric_cols:
    # Currency/Metric Normalization: Cast to double and round to 2 decimals
    df_standardized = df_standardized.withColumn(col_name, F.round(F.col(col_name).cast("double"), 2))

# %%
display(df_standardized.dtypes)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_1</th><th>_2</th></tr></thead><tbody><tr><td>date</td><td>date</td></tr><tr><td>region_name</td><td>string</td></tr><tr><td>days_on_zillow_all_homes</td><td>string</td></tr><tr><td>inventory_seasonally_adjusted_all_homes</td><td>double</td></tr><tr><td>inventory_raw_all_homes</td><td>double</td></tr><tr><td>median_listing_price_per_sqft_1_bedroom</td><td>double</td></tr><tr><td>median_listing_price_per_sqft_2_bedroom</td><td>double</td></tr><tr><td>median_listing_price_per_sqft_3_bedroom</td><td>double</td></tr><tr><td>median_listing_price_per_sqft_4_bedroom</td><td>double</td></tr><tr><td>median_listing_price_per_sqft_5_bedroom_or_more</td><td>double</td></tr><tr><td>median_listing_price_per_sqft_all_homes</td><td>double</td></tr><tr><td>median_listing_price_per_sqft_condo_coop</td><td>double</td></tr><tr><td>median_listing_price_per_sqft_duplex_triplex</td><td>double</td></tr><tr><td>median_listing_price_per_sqft_single_family_residence</td><td>double</td></tr><tr><td>median_listing_price_1_bedroom</td><td>double</td></tr><tr><td>median_listing_price_2_bedroom</td><td>double</td></tr><tr><td>median_listing_price_3_bedroom</td><td>double</td></tr><tr><td>median_listing_price_4_bedroom</td><td>double</td></tr><tr><td>median_listing_price_5_bedroom_or_more</td><td>double</td></tr><tr><td>median_listing_price_all_homes</td><td>double</td></tr><tr><td>median_listing_price_condo_coop</td><td>double</td></tr><tr><td>median_listing_price_duplex_triplex</td><td>double</td></tr><tr><td>median_listing_price_single_family_residence</td><td>double</td></tr><tr><td>median_pct_of_price_reduction_all_homes</td><td>double</td></tr><tr><td>median_pct_of_price_reduction_condo_coop</td><td>double</td></tr><tr><td>median_pct_of_price_reduction_single_family_residence</td><td>double</td></tr><tr><td>median_price_cut_dollar_all_homes</td><td>double</td></tr><tr><td>median_price_cut_dollar_condo_coop</td><td>double</td></tr><tr><td>median_price_cut_dollar_single_family_residence</td><td>double</td></tr><tr><td>median_rental_price_per_sqft_1_bedroom</td><td>double</td></tr><tr><td>median_rental_price_per_sqft_2_bedroom</td><td>double</td></tr><tr><td>median_rental_price_per_sqft_3_bedroom</td><td>double</td></tr><tr><td>median_rental_price_per_sqft_4_bedroom</td><td>double</td></tr><tr><td>median_rental_price_per_sqft_5_bedroom_or_more</td><td>double</td></tr><tr><td>median_rental_price_per_sqft_all_homes</td><td>double</td></tr><tr><td>median_rental_price_per_sqft_condo_coop</td><td>double</td></tr><tr><td>median_rental_price_per_sqft_duplex_triplex</td><td>double</td></tr><tr><td>median_rental_price_per_sqft_multi_family_residence5_plus_units</td><td>double</td></tr><tr><td>median_rental_price_per_sqft_single_family_residence</td><td>double</td></tr><tr><td>median_rental_price_per_sqft_studio</td><td>double</td></tr><tr><td>median_rental_price_1_bedroom</td><td>double</td></tr><tr><td>median_rental_price_2_bedroom</td><td>double</td></tr><tr><td>median_rental_price_3_bedroom</td><td>double</td></tr><tr><td>median_rental_price_4_bedroom</td><td>double</td></tr><tr><td>median_rental_price_5_bedroom_or_more</td><td>double</td></tr><tr><td>median_rental_price_all_homes</td><td>double</td></tr><tr><td>median_rental_price_condo_coop</td><td>double</td></tr><tr><td>median_rental_price_duplex_triplex</td><td>double</td></tr><tr><td>median_rental_price_multi_family_residence5_plus_units</td><td>double</td></tr><tr><td>median_rental_price_single_family_residence</td><td>double</td></tr><tr><td>median_rental_price_studio</td><td>double</td></tr><tr><td>zhviper_sqft_all_homes</td><td>double</td></tr><tr><td>pct_of_homes_decreasing_in_values_all_homes</td><td>double</td></tr><tr><td>pct_of_homes_increasing_in_values_all_homes</td><td>double</td></tr><tr><td>pct_of_homes_selling_for_gain_all_homes</td><td>double</td></tr><tr><td>pct_of_homes_s ...

# %%
df_standardized.write.format("delta").mode("overwrite").option("overwriteSchema", "true").saveAsTable(f"{CATALOG_NAME}.{SCHEMA_SILVER}.county_crosswalk_metrics")

# %% [markdown]
# ## Delta Lake Time Travel Evidence

# %%
display(spark.sql(f"DESCRIBE HISTORY {CATALOG_NAME}.{SCHEMA_SILVER}.county_crosswalk_metrics"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>3</td><td>2026-01-02T19:54:45.000Z</td><td>74222979012178</td><td>saswat.n.behera@v4c.ai</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {"delta.parquet.compression.codec":"zstd","delta.enableDeletionVectors":"true","delta.enableRowTracking":"true","delta.checkpointPolicy":"v2","delta.rowTracking.materializedRowCommitVersionColumnName":"_row-commit-version-col-a74087f6-dfd8-4aed-acfb-bf711f1817bb","delta.rowTracking.materializedRowIdColumnName":"_row-id-col-37eef9ac-3c28-453f-bb8e-9792893ce882"}, statsOnLoad -> true, clusteringOnWriteStatus -> Reason for skipping: Nonexistent clustering column, generally when replacing a Liquid table with a table without clustering columns)</td><td>null</td><td>List(3477484132944233)</td><td>0102-194029-zta1qb9o-v2n</td><td>2</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 1, numRemovedFiles -> 1, numRemovedBytes -> 17551851, numDeletionVectorsRemoved -> 0, numOutputRows -> 155638, numOutputBytes -> 10361834)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>2</td><td>2026-01-02T06:02:18.000Z</td><td>74222979012178</td><td>saswat.n.behera@v4c.ai</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(partitionBy -> [], clusterBy -> ["region_name","date"], description -> null, isManaged -> true, properties -> {"delta.parquet.compression.codec":"zstd","delta.enableDeletionVectors":"true","delta.enableRowTracking":"true","delta.checkpointPolicy":"v2","delta.rowTracking.materializedRowCommitVersionColumnName":"_row-commit-version-col-a74087f6-dfd8-4aed-acfb-bf711f1817bb","delta.rowTracking.materializedRowIdColumnName":"_row-id-col-37eef9ac-3c28-453f-bb8e-9792893ce882"}, statsOnLoad -> true, clusteringOnWriteStatus -> late-stage clustering triggered)</td><td>List(1086061569120203, [dev saswat_n_behera] Zillow_Silver_Enriched, 937874594628388, 1031284339868486, 74222979012178, manual)</td><td>List(963590887321560)</td><td>0102-055617-ws4qs1xd-v2n</td><td>1</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 1, numRemovedFiles -> 1, numRemovedBytes -> 17551849, numDeletionVectorsRemoved -> 0, numOutputRows -> 155638, numOutputBytes -> 17551851)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>1</td><td>2026-01-02T04:12:32.000Z</td><td>74222979012178</td><td>saswat.n.behera@v4c.ai</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(partitionBy -> [], clusterBy -> ["region_name","date"], description -> null, isManaged -> true, properties -> {"delta.parquet.compression.codec":"zstd","delta.enableDeletionVectors":"true","delta.enableRowTracking":"true","delta.checkpointPolicy":"v2","delta.rowTracking.materializedRowCommitVersionColumnName":"_row-commit-version-col-a74087f6-dfd8-4aed-acfb-bf711f1817bb","delta.rowTracking.materializedRowIdColumnName":"_row-id-col-37eef9ac-3c28-453f-bb8e-9792893ce882"}, statsOnLoad -> true, clusteringOnWriteStatus -> late-stage clustering triggered)</td><td>List(580393071454010, Zillow_Silver_Enriched, 233580990431539, 909302618638789, 74222979012178, manual)</td><td>List(963590887321560)</td><td>0102-034516-rko8b1uq-v2n</td><td>0</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 1, numRemovedFiles -> 1, numRemovedBytes -> 17551794, numDeletionVectorsRemoved -> 0, numOutputRows -> 155638, numOutputBytes -> 17551849)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>0</td><td>2026-01-01T11:55:49.000Z ...

# %%
df_v0 = spark.read.option("versionAsOf", 0).table(f"{CATALOG_NAME}.{SCHEMA_SILVER}.county_crosswalk_metrics")

df_latest = spark.table(f"{CATALOG_NAME}.{SCHEMA_SILVER}.county_crosswalk_metrics")

print("VERSION 0:")
df_v0.select("date", "median_listing_price_all_homes").printSchema()

print("LATEST VERSION")
df_latest.select("date", "median_listing_price_all_homes").printSchema()
# Out:
# VERSION 0:
# root
#  |-- date: string (nullable = true)
#  |-- median_listing_price_all_homes: string (nullable = true)
#
# LATEST VERSION
# root
#  |-- date: date (nullable = true)
#  |-- median_listing_price_all_homes: double (nullable = true)

# %%
print("VERSION 0:")
df_v0.printSchema()

print("LATEST VERSION")
df_latest.printSchema()
# Out:
# VERSION 0:
# root
#  |-- date: string (nullable = true)
#  |-- region_name: string (nullable = true)
#  |-- days_on_zillow_all_homes: string (nullable = true)
#  |-- inventory_seasonally_adjusted_all_homes: string (nullable = true)
#  |-- inventory_raw_all_homes: string (nullable = true)
#  |-- median_listing_price_per_sqft_1_bedroom: string (nullable = true)
#  |-- median_listing_price_per_sqft_2_bedroom: string (nullable = true)
#  |-- median_listing_price_per_sqft_3_bedroom: string (nullable = true)
#  |-- median_listing_price_per_sqft_4_bedroom: string (nullable = true)
#  |-- median_listing_price_per_sqft_5_bedroom_or_more: string (nullable = true)
#  |-- median_listing_price_per_sqft_all_homes: string (nullable = true)
#  |-- median_listing_price_per_sqft_condo_coop: string (nullable = true)
#  |-- median_listing_price_per_sqft_duplex_triplex: string (nullable = true)
#  |-- median_listing_price_per_sqft_single_family_residence: string (nullable = true)
#  |-- median_listing_price_1_bedroom: string (nullable = true)
#  |-- median_listing_price_2_bedroom: string (nullable = true)
#  |-- median_listing_price_3_bedroom: string (nullable = true)
#  |-- median_listing_price_4_bedroom: string (nullable = true)
#  |-- median_listing_price_5_bedroom_or_more: string (nullable = true)
#  |-- median_listing_price_all_homes: string (nullable = true)
#  |-- median_listing_price_condo_coop: string (nullable = true)
#  |-- median_listing_price_duplex_triplex: string (nullable = true)
#  |-- median_listing_price_single_family_residence: string (nullable = true)
#  |-- median_pct_of_price_reduction_all_homes: string (nullable = true)
#  |-- median_pct_of_price_reduction_condo_coop: string (nullable = true)
#  |-- median_pct_of_price_reduction_single_family_residence: string (nullable = true)
#  |-- median_price_cut_dollar_all_homes: string (nullable = true)
#  |-- median_price_cut_dollar_condo_coop: string (nullable = true)
#  |-- median_price_cut_dollar_single_family_residence: string (nullable = true)
#  |-- median_rental_price_per_sqft_1_bedroom: string (nullable = true)
#  |-- median_rental_price_per_sqft_2_bedroom: string (nullable = true)
#  |-- median_rental_price_per_sqft_3_bedroom: string (nullable = true)
#  |-- median_rental_price_per_sqft_4_bedroom: string (nullable = true)
#  |-- median_rental_price_per_sqft_5_bedroom_or_more: string (nullable = true)
#  |-- median_rental_price_per_sqft_all_homes: string (nullable = true)
#  |-- median_rental_price_per_sqft_condo_coop: string (nullable = true)
#  |-- median_rental_price_per_sqft_duplex_triplex: string (nullable = true)
#  |-- median_rental_price_per_sqft_multi_family_residence5_plus_units: string (nullable = true)
#  |-- median_rental_price_per_sqft_single_family_residence: string (nullable = true)
#  |-- median_rental_price_per_sqft_studio: string (nullable = true)
#  |-- median_rental_price_1_bedroom: string (nullable = true)
#  |-- median_rental_price_2_bedroom: string (nullable = true)
#  |-- median_rental_price_3_bedroom: string (nullable = true)
#  |-- median_rental_price_4_bedroom: string (nullable = true)
#  |-- median_rental_price_5_bedroom_or_more: string (nullable = true)
#  |-- median_rental_price_all_homes: string (nullable = true)
#  |-- median_rental_price_condo_coop: string (nullable = true)
#  |-- median_rental_price_duplex_triplex: string (nullable = true)
#  |-- median_rental_price_multi_family_residence5_plus_units: string (nullable = true)
#  |-- median_rental_price_single_family_residence: string (nullable = true)
#  |-- median_rental_price_studio: string (nullable = true)
#  |-- zhviper_sqft_all_homes: string (nullable = true)
#  |-- pct_of_homes_decreasing_in_values_all_homes: string (nullable = true)
#  |-- pct_of_homes_increasing_in_values_all_homes: string (nullable = true)
#  |-- pct_of_homes_selling_for_gain_all_homes: string (nullable = true)
#  |-- pct_of_homes_selling_for_loss_all_homes: string (nullable = true)
#  |-- pct_of_listings_with_price_reductions_seas_adj_all_homes: string (nullable = true)
#  |-- pct_of_listings_with_price_reductions_seas_adj_condo_coop: string (nullable = true)
#  |-- pct_of_listings_with_price_reductions_seas_adj_single_family_residence: string (nullable = true)
#  |-- pct_of_listings_with_price_reductions_all_homes: string (nullable = true)
#  |-- pct_of_listings_with_price_reductions_condo_coop: string (nullable = true)
#  |-- pct_of_listings_with_price_reductions_single_family_residence: string (nullable = true)
#  |-- price_to_rent_ratio_all_homes: string (nullable = true)
#  |-- sale_counts: string (nullable = true)
#  |-- sale_counts_seas_adj: string (nullable = true)
#  |-- sale_prices: string (nullable = true)
#  |-- zhvi_1bedroom: string (nullable = true)
#  |-- zhvi_2bedroom: string (nullable = true)
#  |-- zhvi_3bedroom: string (nullable = true)
#  |-- zhvi_4bedroom: string (nullable = true)
#  |-- zhvi_5_bedroom_or_more: string (nullable = true)
#  |-- zhvi_all_homes: string (nullable = true)
#  |-- zhvi_bottom_tier: string (nullable = true)
#  |-- zhvi_condo_coop: string (nullable = true)
#  |-- zhvi_middle_tier: string (nullable = true)
#  |-- zhvi_single_family_residence: string (nullable = true)
#  |-- zhvi_top_tier: string (nullable = true)
#  |-- zri_all_homes: string (nullable = true)
#  |-- zri_all_homes_plus_multifamily: string (nullable = true)
#  |-- zri_per_sqft_all_homes: string (nullable = true)
#  |-- zri_multi_family_residence_rental: string (nullable = true)
#  |-- zri_single_family_residence_rental: string (nullable = true)
#  |-- county_name: string (nullable = true)
#  |-- state_name: string (nullable = true)
#  |-- state_fips: integer (nullable = true)
#  |-- county_fips: integer (nullable = true)
#  |-- metro_name_zillow: string (nullable = true)
#  |-- cbsaname: string (nullable = true)
#  |-- county_region_id_zillow: integer (nullable = true)
#  |-- metro_region_id_zillow: string (nullable = true)
#  |-- cbsacode: string (nullable = true)
#  |-- city: string (nullable = true)
#
# LATEST VERSION
# root
#  |-- date: date (nullable = true)
#  |-- region_name: string (nullable = true)
#  |-- days_on_zillow_all_homes: string (nullable = true)
#  |-- inventory_seasonally_adjusted_all_homes: double (nullable = true)
#  |-- inventory_raw_all_homes: double (nullable = true)
#  |-- median_listing_price_per_sqft_1_bedroom: double (nullable = true)
#  |-- median_listing_price_per_sqft_2_bedroom: double (nullable = true)
#  |-- median_listing_price_per_sqft_3_bedroom: double (nullable = true)
#  |-- median_listing_price_per_sqft_4_bedroom: double (nullable = true)
#  |-- median_listing_price_per_sqft_5_bedroom_or_more: double (nullable = true)
#  |-- median_listing_price_per_sqft_all_homes: double (nullable = true)
#  |-- median_listing_price_per_sqft_condo_coop: double (nullable = true)
#  |-- median_listing_price_per_sqft_duplex_triplex: double (nullable = true)
#  |-- median_listing_price_per_sqft_single_family_residence: double (nullable = true)
#  |-- median_listing_price_1_bedroom: double (nullable = true)
#  |-- median_listing_price_2_bedroom: double (nullable = true)
#  |-- median_listing_price_3_bedroom: double (nullable = true)
#  |-- median_listing_price_4_bedroom: double (nullable = true)
#  |-- median_listing_price_5_bedroom_or_more: double (nullable = true)
#  |-- median_listing_price_all_homes: double (nullable = true)
#  |-- median_listing_price_condo_coop: double (nullable = true)
#  |-- median_listing_price_duplex_triplex: double (nullable = true)
#  |-- median_listing_price_single_family_residence: double (nullable = true)
#  |-- median_pct_of_price_reduction_all_homes: double (nullable = true)
#  |-- median_pct_of_price_reduction_condo_coop: double (nullable = true)
#  |-- median_pct_of_price_reduction_single_family_residence: double (nullable = true)
#  |-- median_price_cut_dollar_all_homes: double (nullable = true)
#  |-- median_price_cut_dollar_condo_coop: double (nullable = true)
#  |-- median_price_cut_dollar_single_family_residence: double (nullable = true)
#  |-- median_rental_price_per_sqft_1_bedroom: double (nullable = true)
#  |-- median_rental_price_per_sqft_2_bedroom: double (nullable = true)
#  |-- median_rental_price_per_sqft_3_bedroom: double (nullable = true)
#  |-- median_rental_price_per_sqft_4_bedroom: double (nullable = true)
#  |-- median_rental_price_per_sqft_5_bedroom_or_more: double (nullable = true)
#  |-- median_rental_price_per_sqft_all_homes: double (nullable = true)
#  |-- median_rental_price_per_sqft_condo_coop: double (nullable = true)
#  |-- median_rental_price_per_sqft_duplex_triplex: double (nullable = true)
#  |-- median_rental_price_per_sqft_multi_family_residence5_plus_units: double (nullable = true)
#  |-- median_rental_price_per_sqft_single_family_residence: double (nullable = true)
#  |-- median_rental_price_per_sqft_studio: double (nullable = true)
#  |-- median_rental_price_1_bedroom: double (nullable = true)
#  |-- median_rental_price_2_bedroom: double (nullable = true)
#  |-- median_rental_price_3_bedroom: double (nullable = true)
#  |-- median_rental_price_4_bedroom: double (nullable = true)
#  |-- median_rental_price_5_bedroom_or_more: double (nullable = true)
#  |-- median_rental_price_all_homes: double (nullable = true)
#  |-- median_rental_price_condo_coop: double (nullable = true)
#  |-- median_rental_price_duplex_triplex: double (nullable = true)
#  |-- median_rental_price_multi_family_residence5_plus_units: double (nullable = true)
#  |-- median_rental_price_single_family_residence: double (nullable = true)
#  |-- median_rental_price_studio: double (nullable = true)
#  |-- zhviper_sqft_all_homes: double (nullable = true)
#  |-- pct_of_homes_decreasing_in_values_all_homes: double (nullable = true)
#  |-- pct_of_homes_increasing_in_values_all_homes: double (nullable = true)
#  |-- pct_of_homes_selling_for_gain_all_homes: double (nullable = true)
#  |-- pct_of_homes_selling_for_loss_all_homes: double (nullable = true)
#  |-- pct_of_listings_with_price_reductions_seas_adj_all_homes: double (nullable = true)
#  |-- pct_of_listings_with_price_reductions_seas_adj_condo_coop: double (nullable = true)
#  |-- pct_of_listings_with_price_reductions_seas_adj_single_family_residence: double (nullable = true)
#  |-- pct_of_listings_with_price_reductions_all_homes: double (nullable = true)
#  |-- pct_of_listings_with_price_reductions_condo_coop: double (nullable = true)
#  |-- pct_of_listings_with_price_reductions_single_family_residence: double (nullable = true)
#  |-- price_to_rent_ratio_all_homes: double (nullable = true)
#  |-- sale_counts: double (nullable = true)
#  |-- sale_counts_seas_adj: double (nullable = true)
#  |-- sale_prices: double (nullable = true)
#  |-- zhvi_1bedroom: double (nullable = true)
#  |-- zhvi_2bedroom: double (nullable = true)
#  |-- zhvi_3bedroom: double (nullable = true)
#  |-- zhvi_4bedroom: double (nullable = true)
#  |-- zhvi_5_bedroom_or_more: double (nullable = true)
#  |-- zhvi_all_homes: double (nullable = true)
#  |-- zhvi_bottom_tier: double (nullable = true)
#  |-- zhvi_condo_coop: double (nullable = true)
#  |-- zhvi_middle_tier: double (nullable = true)
#  |-- zhvi_single_family_residence: double (nullable = true)
#  |-- zhvi_top_tier: double (nullable = true)
#  |-- zri_all_homes: double (nullable = true)
#  |-- zri_all_homes_plus_multifamily: double (nullable = true)
#  |-- zri_per_sqft_all_homes: double (nullable = true)
#  |-- zri_multi_family_residence_rental: double (nullable = true)
#  |-- zri_single_family_residence_rental: double (nullable = true)
#  |-- county_name: string (nullable = true)
#  |-- state_name: string (nullable = true)
#  |-- state_fips: integer (nullable = true)
#  |-- county_fips: integer (nullable = true)
#  |-- metro_name_zillow: string (nullable = true)
#  |-- cbsaname: string (nullable = true)
#  |-- county_region_id_zillow: integer (nullable = true)
#  |-- metro_region_id_zillow: string (nullable = true)
#  |-- cbsacode: string (nullable = true)
#  |-- city: string (nullable = true)
