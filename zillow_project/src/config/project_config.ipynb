# %%
# --- CATALOG NAME ---
CATALOG_NAME = "Zillow"

# --- SCHEMA NAMES ---
SCHEMA_BRONZE = "bronze"
SCHEMA_SILVER = "silver"
SCHEMA_GOLD   = "gold"

VOLUME_LANDING = f"/Volumes/{CATALOG_NAME}/{SCHEMA_BRONZE}/files"
